# %%
import folium
import pandas as pd

# %%
# Create a map centered on Europe
map = folium.Map(location=[50, 15], zoom_start=4)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d23835aa5b54e96e20aa188481a3974 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d23835aa5b54e96e20aa188481a3974&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d23835aa5b54e96e20aa188481a3974 = L.map(
#                 &quot;map_1d23835aa5b54e96e20aa188481a3974&quot;,
#                 {
#                     center: [50.0, 15.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_14b0f7532786a8c11d8b2d0a819bfa78 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1d23835aa5b54e96e20aa188481a3974);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Load the data containing the locations' names, latitude, and longitude
locations = pd.read_csv("Routes_2014_DEU.csv")

# %%
locations = locations.dropna()

# %%
# Add markers for each location to the map
for index, row in locations.iterrows():
    folium.Marker([row['latitude_origin'], row['longitude_origin']], popup=row['origin']).add_to(map)

# %%
# Save the map as an HTML file
map.save("map.html")

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d23835aa5b54e96e20aa188481a3974 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d23835aa5b54e96e20aa188481a3974&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d23835aa5b54e96e20aa188481a3974 = L.map(
#                 &quot;map_1d23835aa5b54e96e20aa188481a3974&quot;,
#                 {
#                     center: [50.0, 15.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_14b0f7532786a8c11d8b2d0a819bfa78 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1d23835aa5b54e96e20aa188481a3974);
#
#
#             var marker_7e33f4f55dd15d1d62d7deec1778128a = L.marker(
#                 [51.289501, 6.76678],
#                 {}
#             ).addTo(map_1d23835aa5b54e96e20aa188481a3974);
#
#
#         var popup_31d80b7306d23890c4d78a430e3b6d3c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b704d4dc816aac6f879b38fcaef6ce61 = $(`&lt;div id=&quot;html_b704d4dc816aac6f879b38fcaef6ce61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;EDDL&lt;/div&gt;`)[0];
#                 popup_31d80b7306d23890c4d78a430e3b6d3c.setContent(html_b704d4dc816aac6f879b38fcaef6ce61);
#
#
#
#         marker_7e33f4f55dd15d1d62d7deec1778128a.bindPopup(popup_31d80b7306d23890c4d78a430e3b6d3c)
#         ;
#
#
#
#
#             var marker_071649d07aaa742fb7d30ba1cc8907fd = L.marker(
#                 [47.67129898, 9.511489868],
#                 {}
#             ).addTo(map_1d23835aa5b54e96e20aa188481a3974);
#
#
#         var popup_412e23cf6f0f3ff752e2dbe8ce0e4c58 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_63e750f4f81e4a60e6849bb644ef1ed2 = $(`&lt;div id=&quot;html_63e750f4f81e4a60e6849bb644ef1ed2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;EDNY&lt;/div&gt;`)[0];
#                 popup_412e23cf6f0f3ff752e2dbe8ce0e4c58.setContent(html_63e750f4f81e4a60e6849bb644ef1ed2);
#
#
#
#         marker_071649d07aaa742fb7d30ba1cc8907fd.bindPopup(popup_412e23cf6f0f3ff752e2dbe8ce0e4c58)
#         ;
#
#
#
#
#             var marker_e09d4ea0d2a53f716022b559e427daa3 = L.marker(
#                 [47.67129898, 9.511489868],
#                 {}
#             ).addTo(map_1d23835aa5b54e96e20aa188481a3974);
#
#
#         var popup_a305e511e6c92512ad4d8ac01349d789 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_65620476114418fde01c8810a956f17c = $(`&lt;div id=&quot;html_65620476114418fde01c8810a956f17c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;EDNY&lt;/div&gt;`)[0];
#                 popup_a305e511e6c92512ad4d8ac01349d789.setContent(html_65620476114418fde01c8810a956f17c);
#
#
#
#         marker_e09d4ea0d2a53f716022b559e427daa3.bindPopup(popup_a305e511e6c92512ad4d8ac01349d789)
#         ;
#
#
#
#
#             var marker_33561886d6294f188a68c7157ec6e374 = L.marker(
#                 [47.67129898, 9.511489868],
#                 {}
#             ).addTo(map_1d23835aa5b54e96e20aa188481a3974);
#
#
#         var popup_369a091f70cf4b03e19db5884107dcec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a754f1b2a25219ac542a8acb5b6ab5ae = $(`&lt;div id=&quot;html_a754f1b2a25219ac542a8acb5b6ab5ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;EDNY&lt;/div&gt;`)[0];
#                 popup_369a091f70cf4b03e19db5884107dcec.setContent(html_a754f1b2a25219ac542a8acb5b6ab5ae);
#
#
#
#         marker_33561886d6294f188a68c7157ec6e374.bindPopup(popup_369a091f70cf4b03e19db5884107dcec)
#         ;
#
#
#
#
#             var marker_0b20c6112bbc6090210b41d36f6896ff = L.marker(
#                 [53.63040161, 9.988229752],
#                 {}
#             ).addTo(map_1d23835aa5b54e96e20aa188481a3974);
#
#
#         var popup_1f9fd700f91325a4b9df84e8b577adc8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f2a5bdf3c879071a0f8e8353384fe172 = $(`&lt;div id=&quot;html_f2a5bdf3c879071a0f8e8353384fe172&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;EDDH&lt;/div&gt;`)[0];
#                 popup_1f9fd700f91325a4b9df84e8b577adc8.setContent(html_f2a5bdf3c879071a0f8e8353384fe172);
#
#
#
#         marker_0b20c6112bbc6090210b41d36f6896ff.bindPopup(popup_1f9fd700f91325a4b9df84e8b577adc8)
#         ;
#
#
#
#
#             var marker_022a14226c80be079b43a4207a900e70 = L.marker(
#                 [52.5597, 13.2877],
#                 {}
#             ).addTo(map_1d23835aa5b54e96e20

# %%
# Create an empty list to store the coordinates of the locations
coords = []

# %%
# Add markers for each location to the map
for index, row in locations.iterrows():
    coords.append([row['latitude_origin'], row['longitude_origin']])
    folium.Marker([row['latitude_origin'], row['longitude_origin']], popup=row['origin']).add_to(map)

# %%
# Connect the locations with lines
folium.PolyLine(coords, color="red", weight=2.5, opacity=1).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d23835aa5b54e96e20aa188481a3974 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d23835aa5b54e96e20aa188481a3974&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d23835aa5b54e96e20aa188481a3974 = L.map(
#                 &quot;map_1d23835aa5b54e96e20aa188481a3974&quot;,
#                 {
#                     center: [50.0, 15.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_14b0f7532786a8c11d8b2d0a819bfa78 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1d23835aa5b54e96e20aa188481a3974);
#
#
#             var marker_7e33f4f55dd15d1d62d7deec1778128a = L.marker(
#                 [51.289501, 6.76678],
#                 {}
#             ).addTo(map_1d23835aa5b54e96e20aa188481a3974);
#
#
#         var popup_31d80b7306d23890c4d78a430e3b6d3c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b704d4dc816aac6f879b38fcaef6ce61 = $(`&lt;div id=&quot;html_b704d4dc816aac6f879b38fcaef6ce61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;EDDL&lt;/div&gt;`)[0];
#                 popup_31d80b7306d23890c4d78a430e3b6d3c.setContent(html_b704d4dc816aac6f879b38fcaef6ce61);
#
#
#
#         marker_7e33f4f55dd15d1d62d7deec1778128a.bindPopup(popup_31d80b7306d23890c4d78a430e3b6d3c)
#         ;
#
#
#
#
#             var marker_071649d07aaa742fb7d30ba1cc8907fd = L.marker(
#                 [47.67129898, 9.511489868],
#                 {}
#             ).addTo(map_1d23835aa5b54e96e20aa188481a3974);
#
#
#         var popup_412e23cf6f0f3ff752e2dbe8ce0e4c58 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_63e750f4f81e4a60e6849bb644ef1ed2 = $(`&lt;div id=&quot;html_63e750f4f81e4a60e6849bb644ef1ed2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;EDNY&lt;/div&gt;`)[0];
#                 popup_412e23cf6f0f3ff752e2dbe8ce0e4c58.setContent(html_63e750f4f81e4a60e6849bb644ef1ed2);
#
#
#
#         marker_071649d07aaa742fb7d30ba1cc8907fd.bindPopup(popup_412e23cf6f0f3ff752e2dbe8ce0e4c58)
#         ;
#
#
#
#
#             var marker_e09d4ea0d2a53f716022b559e427daa3 = L.marker(
#                 [47.67129898, 9.511489868],
#                 {}
#             ).addTo(map_1d23835aa5b54e96e20aa188481a3974);
#
#
#         var popup_a305e511e6c92512ad4d8ac01349d789 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_65620476114418fde01c8810a956f17c = $(`&lt;div id=&quot;html_65620476114418fde01c8810a956f17c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;EDNY&lt;/div&gt;`)[0];
#                 popup_a305e511e6c92512ad4d8ac01349d789.setContent(html_65620476114418fde01c8810a956f17c);
#
#
#
#         marker_e09d4ea0d2a53f716022b559e427daa3.bindPopup(popup_a305e511e6c92512ad4d8ac01349d789)
#         ;
#
#
#
#
#             var marker_33561886d6294f188a68c7157ec6e374 = L.marker(
#                 [47.67129898, 9.511489868],
#                 {}
#             ).addTo(map_1d23835aa5b54e96e20aa188481a3974);
#
#
#         var popup_369a091f70cf4b03e19db5884107dcec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a754f1b2a25219ac542a8acb5b6ab5ae = $(`&lt;div id=&quot;html_a754f1b2a25219ac542a8acb5b6ab5ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;EDNY&lt;/div&gt;`)[0];
#                 popup_369a091f70cf4b03e19db5884107dcec.setContent(html_a754f1b2a25219ac542a8acb5b6ab5ae);
#
#
#
#         marker_33561886d6294f188a68c7157ec6e374.bindPopup(popup_369a091f70cf4b03e19db5884107dcec)
#         ;
#
#
#
#
#             var marker_0b20c6112bbc6090210b41d36f6896ff = L.marker(
#                 [53.63040161, 9.988229752],
#                 {}
#             ).addTo(map_1d23835aa5b54e96e20aa188481a3974);
#
#
#         var popup_1f9fd700f91325a4b9df84e8b577adc8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f2a5bdf3c879071a0f8e8353384fe172 = $(`&lt;div id=&quot;html_f2a5bdf3c879071a0f8e8353384fe172&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;EDDH&lt;/div&gt;`)[0];
#                 popup_1f9fd700f91325a4b9df84e8b577adc8.setContent(html_f2a5bdf3c879071a0f8e8353384fe172);
#
#
#
#         marker_0b20c6112bbc6090210b41d36f6896ff.bindPopup(popup_1f9fd700f91325a4b9df84e8b577adc8)
#         ;
#
#
#
#
#             var marker_022a14226c80be079b43a4207a900e70 = L.marker(
#                 [52.5597, 13.2877],
#                 {}
#             ).addTo(map_1d23835aa5b54e96e20
