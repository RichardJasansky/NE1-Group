# %%
import folium
import numpy as np
import pandas as pd

# %% [markdown]
# # This is the map plotting of the European Airport Network, without edges

# %%
# Create a map centered on Europe
map = folium.Map(location=[50, 15], zoom_start=4)
map_Berlin_2019 = folium.Map(location=[52.5200, 13.4050], zoom_start=12)
map_Berlin_2022 = folium.Map(location=[52.5200, 13.4050], zoom_start=12)

# %%
# Load the data containing the locations' names, latitude, and longitude
locations_2019 = pd.read_csv("EU_routes_2019 (2).csv.gz")
locations_2022 = pd.read_csv("EU_routes_2022.csv.gz")

# %%
locations_2022
# Out:
#       origin_IATA destination_IATA  weight  rec_aircrafts  rec_days  \
# 0             AAH              AGB       1              1         1
# 1             AAH              ALL       1              1         1
# 2             AAH              BFE       1              1         1
# 3             AAH              BNJ       4              4         6
# 4             AAH              BWE       1              1         1
# ...           ...              ...     ...            ...       ...
# 22911         ZRH              XOG       1              1         1
# 22912         ZRH              XRY       1              2         2
# 22913         ZRH              ZAG       1              1         1
# 22914         ZRH              ZHI       5              5         6
# 22915         ZRH              ZJI       1              1         1
#
#             origin_airport_name origin_city origin_country origin_ICAO  \
# 0      Aachen-Merzbrück Airport      Aachen        Germany        EDKA
# 1      Aachen-Merzbrück Airport      Aachen        Germany        EDKA
# 2      Aachen-Merzbrück Airport      Aachen        Germany        EDKA
# 3      Aachen-Merzbrück Airport      Aachen        Germany        EDKA
# 4      Aachen-Merzbrück Airport      Aachen        Germany        EDKA
# ...                         ...         ...            ...         ...
# 22911            Zürich Airport      Zurich    Switzerland        LSZH
# 22912            Zürich Airport      Zurich    Switzerland        LSZH
# 22913            Zürich Airport      Zurich    Switzerland        LSZH
# 22914            Zürich Airport      Zurich    Switzerland        LSZH
# 22915            Zürich Airport      Zurich    Switzerland        LSZH
#
#        origin_latitude  origin_longitude origin_continent  \
# 0            50.823055          6.186389               EU
# 1            50.823055          6.186389               EU
# 2            50.823055          6.186389               EU
# 3            50.823055          6.186389               EU
# 4            50.823055          6.186389               EU
# ...                ...               ...              ...
# 22911        47.464700          8.549170               EU
# 22912        47.464700          8.549170               EU
# 22913        47.464700          8.549170               EU
# 22914        47.464700          8.549170               EU
# 22915        47.464700          8.549170               EU
#
#                         destination_airport_name destination_city  \
# 0                               Augsburg Airport         Augsburg
# 1      Villanova D'Albenga International Airport          Albenga
# 2                              Bielefeld Airport        Bielefeld
# 3                          Bonn-Hangelar Airport   Sankt-Augustin
# 4                 Braunschweig-Wolfsburg Airport     Braunschweig
# ...                                          ...              ...
# 22911           Orange-Caritat (BA 115) Air Base           Orange
# 22912                              Jerez Airport            Jerez
# 22913                             Zagreb Airport           Zagreb
# 22914                           Grenchen Airport         Grenchen
# 22915                            Locarno Airport          Locarno
#
#       destination_country destination_ICAO  destination_latitude  \
# 0                 Germany             EDMA             48.425278
# 1                   Italy             LIMG             44.050600
# 2                 Germany             EDLI             51.964720
# 3                 Germany             EDKB             50.768890
# 4                 Germany             EDVE             52.319200
# ...                   ...              ...                   ...
# 22911              France             LFMO             44.140500
# 22912               Spain             LEJR             36.744600
# 22913             Croatia             LDZA             45.742900
# 22914         Switzerland             LSZG             47.181600
# 22915         Switzerland             LSZL             46.160800
#
#        destination_longitude destination_continent
# 0                  10.931667                    EU
# 1                   8.127430                    EU
# 2                   8.544444                    EU
# 3                   7.163333                    EU
# 4                  10.556100                    EU
# ...                      ...                   ...
# 22911               4.866720                    EU
# 22912              -6.060110                    EU
# 22913              16.068800                    EU
# 22914               7.417190                    EU
# 22915               8.878610                    EU
#
# [22916 rows x 19 columns]

# %%
unique_values = np.unique(locations_2019["origin_country"])
print(unique_values)
# Out:
# ['Austria' 'Belarus' 'Belgium' 'Bulgaria' 'Croatia' 'Czech Republic'
#  'Denmark' 'Estonia' 'Finland' 'France' 'Germany' 'Gibraltar' 'Greece'
#  'Guernsey' 'Hungary' 'Iceland' 'Ireland' 'Isle of Man' 'Italy' 'Jersey'
#  'Latvia' 'Lithuania' 'Luxembourg' 'Macedonia' 'Malta' 'Netherlands'
#  'Norway' 'Poland' 'Portugal' 'Romania' 'Serbia' 'Slovakia' 'Slovenia'
#  'Spain' 'Sweden' 'Switzerland' 'Ukraine' 'United Kingdom']

# %%
locations_2019
# Out:
#      origin_IATA destination_IATA  weight  rec_aircrafts  rec_days  \
# 0            AAL              AAR       2              2         5
# 1            AAL              AGP       1              4         6
# 2            AAL              AMS       3             33        28
# 3            AAL              BRE       2              2         2
# 4            AAL              CPH      28             78        31
# ...          ...              ...     ...            ...       ...
# 7947         ZRH              VRN       2              2         2
# 7948         ZRH              WAW       8             55        31
# 7949         ZRH              WRO       2             17        18
# 7950         ZRH              ZAG       4              5        19
# 7951         ZRH              ZJI       2              2         2
#
#      origin_airport_name origin_city origin_country origin_ICAO  \
# 0        Aalborg Airport     Aalborg        Denmark        EKYT
# 1        Aalborg Airport     Aalborg        Denmark        EKYT
# 2        Aalborg Airport     Aalborg        Denmark        EKYT
# 3        Aalborg Airport     Aalborg        Denmark        EKYT
# 4        Aalborg Airport     Aalborg        Denmark        EKYT
# ...                  ...         ...            ...         ...
# 7947      Zürich Airport      Zurich    Switzerland        LSZH
# 7948      Zürich Airport      Zurich    Switzerland        LSZH
# 7949      Zürich Airport      Zurich    Switzerland        LSZH
# 7950      Zürich Airport      Zurich    Switzerland        LSZH
# 7951      Zürich Airport      Zurich    Switzerland        LSZH
#
#       origin_latitude  origin_longitude origin_continent  \
# 0            57.09276          9.849243               EU
# 1            57.09276          9.849243               EU
# 2            57.09276          9.849243               EU
# 3            57.09276          9.849243               EU
# 4            57.09276          9.849243               EU
# ...               ...               ...              ...
# 7947         47.46470          8.549170               EU
# 7948         47.46470          8.549170               EU
# 7949         47.46470          8.549170               EU
# 7950         47.46470          8.549170               EU
# 7951         47.46470          8.549170               EU
#
#         destination_airport_name destination_city destination_country  \
# 0                 Aarhus Airport           Aarhus             Denmark
# 1                 Málaga Airport           Malaga               Spain
# 2     Amsterdam Airport Schiphol        Amsterdam         Netherlands
# 3                 Bremen Airport           Bremen             Germany
# 4     Copenhagen Kastrup Airport       Copenhagen             Denmark
# ...                          ...              ...                 ...
# 7947  Verona Villafranca Airport      Villafranca               Italy
# 7948       Warsaw Chopin Airport           Warsaw              Poland
# 7949  Copernicus Wrocław Airport          Wroclaw              Poland
# 7950              Zagreb Airport           Zagreb             Croatia
# 7951             Locarno Airport          Locarno         Switzerland
#
#      destination_ICAO  destination_latitude  destination_longitude  \
# 0                EKAH               56.3000               10.61900
# 1                LEMG               36.6749               -4.49911
# 2                EHAM               52.3086                4.76389
# 3                EDDW               53.0475                8.78667
# 4                EKCH               55.6179               12.65600
# ...               ...                   ...                    ...
# 7947             LIPX               45.3957               10.88850
# 7948             EPWA               52.1657               20.96710
# 7949             EPWR               51.1027               16.88580
# 7950             LDZA               45.7429               16.06880
# 7951             LSZL               46.1608                8.87861
#
#      destination_continent
# 0                       EU
# 1                       EU
# 2                       EU
# 3                       EU
# 4                       EU
# ...                    ...
# 7947                    EU
# 7948                    EU
# 7949                    EU
# 7950                    EU
# 7951                    EU
#
# [7952 rows x 19 columns]

# %%
# Add markers for each location to the map
for index, row in locations_2019.iterrows():
    folium.Marker([row['origin_latitude'], row['origin_longitude']], popup=row['origin_airport_name']).add_to(map)

# %%
#map

# %% [markdown]
# #This is a zoom-in on the European Network to the Berlin case. This plot shows the nodes connected through the edges (unweighted)

# %%
#Berlin_2019 = locations_2019[(locations_2019["origin_city"]=="Berlin")|(locations_2019["destination_city"]=="Berlin")]

# %%
Berlin_2019 = locations_2019[(locations_2019["origin_city"]=="Berlin")]
Berlin_2022 = locations_2022[(locations_2022["origin_city"]=="Berlin")]

# %%
Berlin_2019
# Out:
#      origin_IATA destination_IATA  weight  rec_aircrafts  rec_days  \
# 6866         SXF              AGP       3             25        20
# 6867         SXF              ALC       1             10        12
# 6868         SXF              AMS       6             35        31
# 6869         SXF              ARN       3             35        27
# 6870         SXF              ATH       2             21        24
# ...          ...              ...     ...            ...       ...
# 7331         TXL              VIE      16             87        31
# 7332         TXL              VNO       2              3         5
# 7333         TXL              WAW       2             15        20
# 7334         TXL              ZAG       1              8        17
# 7335         TXL              ZRH      23             97        31
#
#             origin_airport_name origin_city origin_country origin_ICAO  \
# 6866  Berlin-Schönefeld Airport      Berlin        Germany        EDDB
# 6867  Berlin-Schönefeld Airport      Berlin        Germany        EDDB
# 6868  Berlin-Schönefeld Airport      Berlin        Germany        EDDB
# 6869  Berlin-Schönefeld Airport      Berlin        Germany        EDDB
# 6870  Berlin-Schönefeld Airport      Berlin        Germany        EDDB
# ...                         ...         ...            ...         ...
# 7331       Berlin-Tegel Airport      Berlin        Germany        EDDT
# 7332       Berlin-Tegel Airport      Berlin        Germany        EDDT
# 7333       Berlin-Tegel Airport      Berlin        Germany        EDDT
# 7334       Berlin-Tegel Airport      Berlin        Germany        EDDT
# 7335       Berlin-Tegel Airport      Berlin        Germany        EDDT
#
#       origin_latitude  origin_longitude origin_continent  \
# 6866          52.3800           13.5225               EU
# 6867          52.3800           13.5225               EU
# 6868          52.3800           13.5225               EU
# 6869          52.3800           13.5225               EU
# 6870          52.3800           13.5225               EU
# ...               ...               ...              ...
# 7331          52.5597           13.2877               EU
# 7332          52.5597           13.2877               EU
# 7333          52.5597           13.2877               EU
# 7334          52.5597           13.2877               EU
# 7335          52.5597           13.2877               EU
#
#                          destination_airport_name destination_city  \
# 6866                               Málaga Airport           Malaga
# 6867               Alicante International Airport         Alicante
# 6868                   Amsterdam Airport Schiphol        Amsterdam
# 6869                    Stockholm-Arlanda Airport        Stockholm
# 6870  Eleftherios Venizelos International Airport           Athens
# ...                                           ...              ...
# 7331                 Vienna International Airport           Vienna
# 7332                Vilnius International Airport          Vilnius
# 7333                        Warsaw Chopin Airport           Warsaw
# 7334                               Zagreb Airport           Zagreb
# 7335                               Zürich Airport           Zurich
#
#      destination_country destination_ICAO  destination_latitude  \
# 6866               Spain             LEMG               36.6749
# 6867               Spain             LEAL               38.2822
# 6868         Netherlands             EHAM               52.3086
# 6869              Sweden             ESSA               59.6519
# 6870              Greece             LGAV               37.9364
# ...                  ...              ...                   ...
# 7331             Austria             LOWW               48.1103
# 7332           Lithuania             EYVI               54.6341
# 7333              Poland             EPWA               52.1657
# 7334             Croatia             LDZA               45.7429
# 7335         Switzerland             LSZH               47.4647
#
#       destination_longitude destination_continent
# 6866              -4.499110                    EU
# 6867              -0.558156                    EU
# 6868               4.763890                    EU
# 6869              17.918600                    EU
# 6870              23.944500                    EU
# ...                     ...                   ...
# 7331              16.569700                    EU
# 7332              25.285800                    EU
# 7333              20.967100                    EU
# 7334              16.068800                    EU
# 7335               8.549170                    EU
#
# [164 rows x 19 columns]

# %%
# Create an empty list to store the coordinates of the locations
coords = []

# %%
# Add markers for each location to the map
#for index, row in Berlin_2019.iterrows():
    #coords.append([row['destination_latitude'], row['destination_longitude'], row['origin_latitude'], row['origin_longitude']])
   # folium.Marker([row['origin_latitude'], row['origin_longitude']], popup=row['origin_airport_name']).add_to(map_Berlin)

# %%
#Adds edges between airports for 2019 map
for i, edge in Berlin_2019.iterrows():
    folium.PolyLine([[edge['origin_latitude'], edge['origin_longitude']],
                     [edge['destination_latitude'], edge['destination_longitude']]],
                    #weight=edge['weight'],
                    color='black',
                    opacity=0.3).add_to(map_Berlin_2019)

# %%
#Adds edges between airports for 2022 map
for i, edge in Berlin_2022.iterrows():
    folium.PolyLine([[edge['origin_latitude'], edge['origin_longitude']],
                     [edge['destination_latitude'], edge['destination_longitude']]],
                    #weight=edge['weight'],
                    color='black',
                    opacity=0.3).add_to(map_Berlin_2022)

# %%
# Connect the locations with lines
#folium.PolyLine(coords, color="red", opacity=1).add_to(map_Berlin)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# File c:\Users\Gamebore2\miniconda3\envs\myenv\lib\site-packages\folium\utilities.py:99, in validate_locations(locations)
#      98 try:
# ---> 99     next(iter(locations))
#     100 except StopIteration:
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 2
#       1 # Connect the locations with lines
# ----> 2 folium.PolyLine(coords, color="red", opacity=1).add_to(map_Berlin)
#
# File c:\Users\Gamebore2\miniconda3\envs\myenv\lib\site-packages\folium\vector_layers.py:169, in PolyLine.__init__(self, locations, popup, tooltip, **kwargs)
#     168 def __init__(self, locations, popup=None, tooltip=None, **kwargs):
# --> 169     super().__init__(locations, popup=popup, tooltip=tooltip)
#     170     self._name = "PolyLine"
#     171     self.options = path_options(line=True, **kwargs)
#
# File c:\Users\Gamebore2\miniconda3\envs\myenv\lib\site-packages\folium\vector_layers.py:119, in BaseMultiLocation.__init__(self, locations, popup, tooltip)
#     117 def __init__(self, locations, popup=None, tooltip=None):
#     118     super().__init__()
# --> 119     self.locations = validate_locations(locations)
#     120     if popup is not None:
#     121         self.add_child(popup if isinstance(popup, Popup) else Popup(str(popup)))
#
# File c:\Users\Gamebore2\miniconda3\envs\myenv\lib\site-packages\folium\utilities.py:101, in validate_locations(locations)
#      99     next(iter(locations))
#     100 except StopIteration:
# --> 101     raise ValueError("Locations is empty.")
#     102 try:
#     103     float(next(iter(next(iter(next(iter(locations)))))))
#
# ValueError: Locations is empty.

# %%
map_Berlin_2019
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_206039e29f55cdcdac4bcadc05fa9088 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_206039e29f55cdcdac4bcadc05fa9088&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_206039e29f55cdcdac4bcadc05fa9088 = L.map(
#                 &quot;map_206039e29f55cdcdac4bcadc05fa9088&quot;,
#                 {
#                     center: [52.52, 13.405],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5aa939471bcf1b138b40e1f46d85a54c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_206039e29f55cdcdac4bcadc05fa9088);
#
#
#             var poly_line_98aac85e8923195a0fbbefa2a392aa31 = L.polyline(
#                 [[52.38, 13.5225], [36.6749, -4.49911]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.3, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_206039e29f55cdcdac4bcadc05fa9088);
#
#
#             var poly_line_067d386f21c5982a26d530fe2b2fb15a = L.polyline(
#                 [[52.38, 13.5225], [38.2822, -0.558156]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.3, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_206039e29f55cdcdac4bcadc05fa9088);
#
#
#             var poly_line_131e54d439902956ee831ad954b279a4 = L.polyline(
#                 [[52.38, 13.5225], [52.3086, 4.76389]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.3, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_206039e29f55cdcdac4bcadc05fa9088);
#
#
#             var poly_line_383f57f89f9a3f80b59b479652114b9f = L.polyline(
#                 [[52.38, 13.5225], [59.6519, 17.9186]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.3, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_206039e29f55cdcdac4bcadc05fa9088);
#
#
#             var poly_line_0cc766b4f0a258b6e7258f7e767c1d4f = L.polyline(
#                 [[52.38, 13.5225], [37.9364, 23.9445]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.3, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_206039e29f55cdcdac4bcadc05fa9088);
#
#
#             var poly_line_62cc9ba1ba231612c583b340fac91460 = L.polyline(
#                 [[52.38, 13.5225], [38.8833, -9.0301]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity

# %%
map_Berlin_2022
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4095408b6a23601a461f5e11d6c1ab3c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4095408b6a23601a461f5e11d6c1ab3c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4095408b6a23601a461f5e11d6c1ab3c = L.map(
#                 &quot;map_4095408b6a23601a461f5e11d6c1ab3c&quot;,
#                 {
#                     center: [52.52, 13.405],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_21dbd5cbc290fd3aff220dec34f30f8d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4095408b6a23601a461f5e11d6c1ab3c);
#
#
#             var poly_line_eff68494cffffaa399c13c8076e53e36 = L.polyline(
#                 [[52.38, 13.5225], [57.09276, 9.849243]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.3, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4095408b6a23601a461f5e11d6c1ab3c);
#
#
#             var poly_line_52c20a6548eb0ce8d6ce2c7d05ceb3f5 = L.polyline(
#                 [[52.38, 13.5225], [47.485, 9.56077]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.3, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4095408b6a23601a461f5e11d6c1ab3c);
#
#
#             var poly_line_3ee3b39167eb0867f316c1efad57bd56 = L.polyline(
#                 [[52.38, 13.5225], [48.425278, 10.931667]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.3, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4095408b6a23601a461f5e11d6c1ab3c);
#
#
#             var poly_line_094c0a195103fc206591ad83153a82ff = L.polyline(
#                 [[52.38, 13.5225], [56.2961, 12.8471]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.3, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4095408b6a23601a461f5e11d6c1ab3c);
#
#
#             var poly_line_0bd6cb73e9b36da8a286491eab5bbfea = L.polyline(
#                 [[52.38, 13.5225], [36.6749, -4.49911]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.3, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4095408b6a23601a461f5e11d6c1ab3c);
#
#
#             var poly_line_e2c8a7a10bb2f8a2bc606e6d45089427 = L.polyline(
#                 [[52.38, 13.5225], [38.2822, -0.558156]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;op

# %% [markdown]
# *Alternative process / Weighted network*
